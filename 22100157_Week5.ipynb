# %% [markdown]
# Score Announcement

# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import nltk
from bs4 import BeautifulSoup
import string
from nltk.corpus import stopwords

# %% [markdown]
# ### 1. Read in csv file and create Dataframe & check shape.

# %%
train_df = pd.read_csv("amazon_train_df.csv")
test_df = pd.read_csv("amazon_test_df.csv")
print(train_df.shape, test_df.shape)

tmp_tr = train_df
tmp_te = test_df
# Out:
# (500, 5) (25, 5)

# %%
train_df.head()
# Out:
#                         0    1               2  \
# 0               One Star   1.0   25 July 2014
# 1          Arm missing!!   1.0    1 Nov. 2015
# 2  Cheap advent calendar   1.0   28 Oct. 2015
# 3      Poor quality sand   1.0   26 Dec. 2015
# 4          Colour choice   1.0   19 Dec. 2015
#
#                                                    3  \
# 0   By\n    \n    Andrea Bradden\n  \n on 25 July...
# 1    By\n    \n    gemma james\n  \n on 1 Nov. 2015
# 2         By\n    \n    lully\n  \n on 28 Oct. 2015
# 3   By\n    \n    Amazon Customer\n  \n on 26 Dec...
# 4      By\n    \n    Pen Name\n  \n on 19 Dec. 2015
#
#                                                    4
# 0   ordered this, there was no PB embroidered on ...
# 1   These are smaller than than you think and a l...
# 2   Thought this would make a lovely different ca...
# 3   The sand is rubbish - very messy and doesn't ...
# 4   Know it says random colours but wish we could...

# %%
train_df.iloc[4,4]
# Out:
# " Know it says random colours but wish we could choose. Red is quite dark and my girlie girl won't like it and will surely wonder why Santa has given her a colour she doesn't like! "

# %% [markdown]
# ### 2. Cleaning( Remove HTML )

# %%
## Add new columns to 'review_df' or change the column name
train_df.columns = ['review_title','rating','review_date','customer_name','review']
test_df.columns = ['review_title','rating','review_date','customer_name','review']

# %%
train_df
# Out:
#                                           review_title  rating  \
# 0                                            One Star      1.0
# 1                                       Arm missing!!      1.0
# 2                               Cheap advent calendar      1.0
# 3                                   Poor quality sand      1.0
# 4                                       Colour choice      1.0
# ..                                                 ...     ...
# 495                                        Five Stars      5.0
# 496                                        Five Stars      5.0
# 497  Fantastic detail! A beautiful model traction e...     5.0
# 498                                 very good quality      5.0
# 499                                         Excellent      5.0
#
#          review_date                                      customer_name  \
# 0      25 July 2014    By\n    \n    Andrea Bradden\n  \n on 25 July...
# 1       1 Nov. 2015     By\n    \n    gemma james\n  \n on 1 Nov. 2015
# 2      28 Oct. 2015          By\n    \n    lully\n  \n on 28 Oct. 2015
# 3      26 Dec. 2015    By\n    \n    Amazon Customer\n  \n on 26 Dec...
# 4      19 Dec. 2015       By\n    \n    Pen Name\n  \n on 19 Dec. 2015
# ..               ...                                                ...
# 495   29 Sept. 2014    By\n    \n    D. G. Long\n  \n on 29 Sept. 2014
# 496     5 Jan. 2016    By\n    \n    Paul Cavanagh\n  \n on 5 Jan. 2...
# 497    23 Nov. 2015            By\n    \n    JET\n  \n on 23 Nov. 2015
# 498     7 July 2013           By\n    \n    Storm\n  \n on 7 July 2013
# 499   30 April 2011          By\n    \n    Ella\n  \n on 30 April 2011
#
#                                                 review
# 0     ordered this, there was no PB embroidered on ...
# 1     These are smaller than than you think and a l...
# 2     Thought this would make a lovely different ca...
# 3     The sand is rubbish - very messy and doesn't ...
# 4     Know it says random colours but wish we could...
# ..                                                 ...
# 495   My daughter loves this and runs and jumps abo...
# 496                                        Great model
# 497   Fantastic detail! A beautiful model traction ...
# 498   easy to couple with other models, great to ex...
# 499   I bought this for my 2 year old grandson and ...
#
# [500 rows x 5 columns]

# %%
def remove_html(text):
    soup = BeautifulSoup(text, 'lxml')
    return soup.get_text()

train_df['review'].apply(lambda x: remove_html(x))
test_df['review'].apply(lambda x: remove_html(x) )
train_df.head()
# Out:
# /var/folders/kn/3ppgqctj38z5rc5jyytkxp900000gp/T/ipykernel_1647/1542110540.py:2: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, 'lxml')
#              review_title  rating     review_date  \
# 0               One Star      1.0   25 July 2014
# 1          Arm missing!!      1.0    1 Nov. 2015
# 2  Cheap advent calendar      1.0   28 Oct. 2015
# 3      Poor quality sand      1.0   26 Dec. 2015
# 4          Colour choice      1.0   19 Dec. 2015
#
#                                        customer_name  \
# 0   By\n    \n    Andrea Bradden\n  \n on 25 July...
# 1    By\n    \n    gemma james\n  \n on 1 Nov. 2015
# 2         By\n    \n    lully\n  \n on 28 Oct. 2015
# 3   By\n    \n    Amazon Customer\n  \n on 26 Dec...
# 4      By\n    \n    Pen Name\n  \n on 19 Dec. 2015
#
#                                               review
# 0   ordered this, there was no PB embroidered on ...
# 1   These are smaller than than you think and a l...
# 2   Thought this would make a lovely different ca...
# 3   The sand is rubbish - very messy and doesn't ...
# 4   Know it says random colours but wish we could...

# %% [markdown]
# ### 3. Remove punctuation(구두점) & lower case

# %%
print('Punctuation: ', string.punctuation)
# Out:
# Punctuation:  !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def remove_punctuation(text):
    sent = []
    for t in text.split(' '):
        no_punct = "".join([c for c in t if c not in string.punctuation])
        sent.append(no_punct)

    sentence = " ".join(s for s in sent)
    sentence = sentence.lower()
    return sentence

# %%
## apply remove_punctuation function
train_df['review'] = train_df['review'].apply( remove_punctuation)
train_df['review_title'] = train_df['review_title'].apply( remove_punctuation)

test_df['review'] = test_df['review'].apply( remove_punctuation)
test_df['review_title'] =  test_df['review_title'].apply( remove_punctuation)
train_df.head()
# Out:
#              review_title  rating     review_date  \
# 0               one star      1.0   25 July 2014
# 1            arm missing      1.0    1 Nov. 2015
# 2  cheap advent calendar      1.0   28 Oct. 2015
# 3      poor quality sand      1.0   26 Dec. 2015
# 4          colour choice      1.0   19 Dec. 2015
#
#                                        customer_name  \
# 0   By\n    \n    Andrea Bradden\n  \n on 25 July...
# 1    By\n    \n    gemma james\n  \n on 1 Nov. 2015
# 2         By\n    \n    lully\n  \n on 28 Oct. 2015
# 3   By\n    \n    Amazon Customer\n  \n on 26 Dec...
# 4      By\n    \n    Pen Name\n  \n on 19 Dec. 2015
#
#                                               review
# 0   ordered this there was no pb embroidered on t...
# 1   these are smaller than than you think and a l...
# 2   thought this would make a lovely different ca...
# 3   the sand is rubbish  very messy and doesnt st...
# 4   know it says random colours but wish we could...

# %% [markdown]
# ### 4. Lemmatization or Stemming

# %%
## using spacy
# !python -m spacy download en
import spacy

nlp = spacy.load('en_core_web_sm')

# %%
# Copy original DataFrames for Stemming
train_df_stem = train_df.copy()
test_df_stem = test_df.copy()

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()

def tokenize_and_stem(text):
    tokens =word_tokenize(text) #tokenize
    return [stemmer.stem(token) for token in tokens] #stem the tokens

# stemming
train_df_stem['review'] = train_df_stem['review'].apply(tokenize_and_stem)
train_df_stem['review_title'] = train_df_stem['review_title'].apply(tokenize_and_stem)

test_df_stem['review'] = test_df_stem['review'].apply(tokenize_and_stem)
test_df_stem['review_title'] = test_df_stem['review_title'].apply(tokenize_and_stem)
test_df_stem.head()
# Out:
# [nltk_data] Downloading package punkt to /Users/woo-hyun/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /Users/woo-
# [nltk_data]     hyun/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#                                        review_title  rating      review_date  \
# 0         [and, my, grandson, wa, huge, disappoint]     1.0     24 May 2015
# 1  [incorrect, answer, to, some, of, the, question]     1.0    20 Aug. 2014
# 2                         [dont, wast, your, money]     1.0     6 Feb. 2012
# 3                                 [broken, present]     1.0    24 Feb. 2015
# 4                                       [unimpress]     1.0   11 April 2012
#
#                                        customer_name  \
# 0   By\n    \n    Josephine Chetter\n  \n on 24 M...
# 1        By\n    \n    Alison\n  \n on 20 Aug. 2014
# 2    By\n    \n    L. Turnbull\n  \n on 6 Feb. 2012
# 3   By\n    \n    karen yates\n  \n on 24 Feb. 2015
# 4       By\n    \n    b4time\n  \n on 11 April 2012
#
#                                               review
# 0  [my, daughter, had, bought, the, appropri, vte...
# 1  [a, good, game, if, all, the, answer, were, co...
# 2  [ok, thi, didnt, cost, a, lot, but, neverthele...
# 3  [i, bought, 2, of, these, for, my, grandson, f...
# 4  [the, d20, is, not, a, regular, shapeth, 11, i...

# %%
# Copy original DataFrames for Lemmatizing
train_df_lemma = train_df.copy()
test_df_lemma = test_df.copy()

# %%
def word_lemmatizer(text):
    doc = nlp(text.strip()) 
    lemmatized = [token.lemma_ for token in doc]    

    return lemmatized

## tokenization & lemmatization
train_df_lemma['review'] = train_df_lemma['review'].apply(lambda x: word_lemmatizer(x))
train_df_lemma['review_title'] = train_df_lemma['review_title'].apply(lambda x: word_lemmatizer(x))

test_df_lemma['review'] = test_df_lemma['review'].apply(lambda x: word_lemmatizer(x))
test_df_lemma['review_title'] = test_df_lemma['review_title'].apply(lambda x: word_lemmatizer(x))
test_df_lemma.head()
# Out:
#                                        review_title  rating      review_date  \
# 0     [and, my, grandson, be, hugely, disappointed]     1.0     24 May 2015
# 1  [incorrect, answer, to, some, of, the, question]     1.0    20 Aug. 2014
# 2                     [do, not, waste, your, money]     1.0     6 Feb. 2012
# 3                                 [broken, present]     1.0    24 Feb. 2015
# 4                                     [unimpressed]     1.0   11 April 2012
#
#                                        customer_name  \
# 0   By\n    \n    Josephine Chetter\n  \n on 24 M...
# 1        By\n    \n    Alison\n  \n on 20 Aug. 2014
# 2    By\n    \n    L. Turnbull\n  \n on 6 Feb. 2012
# 3   By\n    \n    karen yates\n  \n on 24 Feb. 2015
# 4       By\n    \n    b4time\n  \n on 11 April 2012
#
#                                               review
# 0  [my, daughter, have, buy, the, appropriate, vt...
# 1  [a, good, game, if, all, the, answer, be, corr...
# 2  [ok, this, do, not, cost, a, lot, but, neverth...
# 3  [I, buy, 2, of, these, for, my, grandson, for,...
# 4  [the, d20, be, not, a, regular, shapethe, 11, ...

# %%
# Copy original DataFrames for pos-tag
train_df_pos = train_df.copy()
test_df_pos = test_df.copy()

# %%
from nltk import pos_tag

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')

def tokenize_and_pos(text):
    tokens = word_tokenize(text) #tokenize
    tagged = pos_tag(tokens) #POS tagging
    return tagged
# POS tagging

train_df_pos['review'] = train_df_pos['review'].apply(tokenize_and_pos)
train_df_pos['review_title'] = train_df_pos['review_title'].apply(tokenize_and_pos)

test_df_pos['review'] = test_df_pos['review'].apply(tokenize_and_pos)
test_df_pos['review_title'] = test_df_pos['review_title'].apply(tokenize_and_pos)
test_df_pos.head()

print("POS Tags for 'review':")
for word, tag in test_df_pos.iloc[0]['review']:
    print(f"{word} --> {tag}")

print("\nPOS Tags for 'review_title':")
for word, tag in test_df_pos.iloc[0]['review_title']:
    print(f"{word} --> {tag}")
# Out:
# [nltk_data] Downloading package punkt to /Users/woo-hyun/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/woo-hyun/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# POS Tags for 'review':
# my --> PRP$
# daughter --> NN
# had --> VBD
# bought --> VBN
# the --> DT
# appropriate --> JJ
# vtech --> NN
# innotab --> NN
# max --> VBD
# the --> DT
# previous --> JJ
# week --> NN
# for --> IN
# her --> PRP$
# sons --> NNS
# birthday --> VBP
# i --> JJ
# bought --> VBD
# the --> DT
# toy --> NN
# story --> NN
# software --> NN
# to --> TO
# go --> VB
# with --> IN
# it --> PRP
# which --> WDT
# had --> VBD
# a --> DT
# sticker --> NN
# on --> IN
# it --> PRP
# stating --> VBG
# it --> PRP
# worked --> VBD
# with --> IN
# the --> DT
# innotab --> NN
# max --> NN
# however --> RB
# when --> WRB
# we --> PRP
# tried --> VBD
# it --> PRP
# on --> IN
# his --> PRP$
# birthday --> NN
# a --> DT
# message --> NN
# came --> VBD
# up --> RB
# on --> IN
# the --> DT
# screen --> NN
# saying --> VBG
# the --> DT
# software --> NN
# wasnt --> NN
# compatible --> JJ
# despite --> IN
# it --> PRP
# saying --> VBG
# on --> IN
# the --> DT
# packaging --> NN
# that --> IN
# it --> PRP
# worked --> VBD
# with --> IN
# all --> PDT
# the --> DT
# vtech --> JJ
# innotab --> NN
# i --> NN
# discovered --> VBD
# that --> IN
# the --> DT
# hardware --> NN
# had --> VBD
# to --> TO
# be --> VB
# updated --> VBN
# and --> CC
# therefore --> RB
# had --> VBD
# to --> TO
# download --> VB
# the --> DT
# update --> NN
# before --> IN
# the --> DT
# toy --> NN
# story --> NN
# software --> NN
# could --> MD
# be --> VB
# used --> VBN
# i --> RB
# found --> VBD
# this --> DT
# info --> NN
# purely --> RB
# by --> IN
# chance --> NN
# on --> IN
# another --> DT
# review --> NN
# site --> NN
# i --> NN
# considered --> VBD
# the --> DT
# information --> NN
# on --> IN
# the --> DT
# game --> NN
# misleading --> VBG
# saying --> VBG
# it --> PRP
# would --> MD
# work --> VB
# with --> IN
# all --> DT
# innotab --> NN
# and --> CC
# it --> PRP
# didnt --> RB
# and --> CC
# my --> PRP$
# grandson --> NN
# was --> VBD
# hugely --> RB
# disappointed --> JJ
#
# POS Tags for 'review_title':
# and --> CC
# my --> PRP$
# grandson --> NN
# was --> VBD
# hugely --> RB
# disappointed --> JJ

# %%
"""
POS

CC: It is the conjunction of coordinating
CD: It is a digit of cardinal
DT: It is the determiner
EX: Existential
FW: It is a foreign word
IN: Preposition and conjunction
JJ: Adjective
JJR and JJS: Adjective and superlative
LS: List marker
MD: Modal
NN: Singular noun
NNS, NNP, NNPS: Proper and plural noun
PDT: Predeterminer
WRB: Adverb of wh
WP$: Possessive wh
WP: Pronoun of wh
WDT: Determiner of wp
VBZ: Verb
VBP, VBN, VBG, VBD, VB: Forms of verbs
UH: Interjection
TO: To go
RP: Particle
RBS, RB, RBR: Adverb
PRP, PRP$: Pronoun personal and professional

"""
# Out:
# '\nPOS\n\nCC: It is the conjunction of coordinating\nCD: It is a digit of cardinal\nDT: It is the determiner\nEX: Existential\nFW: It is a foreign word\nIN: Preposition and conjunction\nJJ: Adjective\nJJR and JJS: Adjective and superlative\nLS: List marker\nMD: Modal\nNN: Singular noun\nNNS, NNP, NNPS: Proper and plural noun\nPDT: Predeterminer\nWRB: Adverb of wh\nWP$: Possessive wh\nWP: Pronoun of wh\nWDT: Determiner of wp\nVBZ: Verb\nVBP, VBN, VBG, VBD, VB: Forms of verbs\nUH: Interjection\nTO: To go\nRP: Particle\nRBS, RB, RBR: Adverb\nPRP, PRP$: Pronoun personal and professional\n\n'

# %% [markdown]
# ### 5. Remove stop words(불용어)

# %%
## remove stopwords
nltk.download('stopwords')

def remove_stopwords(text):
    words = [w for w in text if w not in stopwords.words('english')]
    return words

train_df_lemma['review'] = train_df_lemma['review'].apply(lambda x: remove_stopwords(x))
train_df_lemma['review_title'] = train_df_lemma['review_title'].apply(lambda x: remove_stopwords(x))

test_df_lemma['review'] = test_df_lemma['review'].apply(lambda x: remove_stopwords(x))
test_df_lemma['review_title'] = test_df_lemma['review_title'].apply(lambda x: remove_stopwords(x))
# Out:
# [nltk_data] Downloading package stopwords to /Users/woo-
# [nltk_data]     hyun/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
train_df_lemma.head()
# Out:
#                 review_title  rating     review_date  \
# 0                [one, star]     1.0   25 July 2014
# 1                [arm, miss]     1.0    1 Nov. 2015
# 2  [cheap, advent, calendar]     1.0   28 Oct. 2015
# 3      [poor, quality, sand]     1.0   26 Dec. 2015
# 4           [colour, choice]     1.0   19 Dec. 2015
#
#                                        customer_name  \
# 0   By\n    \n    Andrea Bradden\n  \n on 25 July...
# 1    By\n    \n    gemma james\n  \n on 1 Nov. 2015
# 2         By\n    \n    lully\n  \n on 28 Oct. 2015
# 3   By\n    \n    Amazon Customer\n  \n on 26 Dec...
# 4      By\n    \n    Pen Name\n  \n on 19 Dec. 2015
#
#                                               review
# 0  [order, pb, embroider, coat, opposite, colour,...
# 1  [small, think, little, price, worth, £, 5,  , ...
# 2  [think, would, make, lovely, different, calend...
# 3  [sand, rubbish,  , messy, stick, together, lik...
# 4  [know, say, random, colour, wish, could, choos...

# %% [markdown]
# ### 6. Make a dictionary

# %%
# save the data after removing stopwords
import numpy as np

five_rating_dict = {}

def make_dict(review, rating):
    for e in review:
        if e not in five_rating_dict and e != '\n':
            five_rating_dict[e] = np.zeros(5)

        five_rating_dict[e][int(rating)-1] += 1

for index, row in train_df_lemma.iterrows():
    rating = row['rating']
    make_dict(row['review'], rating)
    make_dict(row['review_title'], rating)

# %%
len(five_rating_dict)
# Out:
# 3642

# %%
max_dict = {}
max_dict = {k: five_rating_dict[k].argmax()+1 for k in five_rating_dict.keys()}

# %%
print(len(max_dict))

max_dict['<OOV>'] = 3 # the median of rating
print(len(max_dict))
# Out:
# 3642
# 3643

# %%
print('frequency of unfortunately: ', five_rating_dict['unfortunately'])
print('frequency of good: ',five_rating_dict['good'])
# Out:
# frequency of unfortunately:  [6. 9. 1. 2. 1.]
# frequency of good:  [16. 39. 52. 53. 37.]

# %% [markdown]
# ### Result❗️
# dictionary of unfortunately:  [6. 9. 1. 2. 1.] <br>
# dictionary of good:  [16. 39. 52. 53. 37.] <br>

# %%
## check the dictionary's value
print('rating of unfortunately: ', max_dict['unfortunately'])
print('rating of bad: ', max_dict['frustrated'])
print('rating of good: ', max_dict['good'])
print('rating of great: ', max_dict['great'])
# Out:
# rating of unfortunately:  2
# rating of bad:  1
# rating of good:  4
# rating of great:  5

# %% [markdown]
# ### Result❗️
# rating of unfortunately:  2 <br>
# rating of bad:  1 <br>
# rating of good:  4 <br>
# rating of great:  5

# %% [markdown]
# ## 7. Word Embeding

# %%
# !pip install gensim
#!pip uninstall numpy
#!pip install numpy==1.24.3
#!pip install scipy
# Out:
# Requirement already satisfied: gensim in /opt/anaconda3/lib/python3.12/site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /opt/anaconda3/lib/python3.12/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/anaconda3/lib/python3.12/site-packages (from gensim) (5.2.1)

# %%
from gensim.models import Word2Vec
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import numpy as np

# Combine all reviews and titles for training Word2Vec
corpus = list(train_df_lemma['review']) + list(train_df_lemma['review_title'])
w2v_model = Word2Vec(sentences=corpus, vector_size=100, window=10, min_count=10, workers=4)

# %%
top_5_words = w2v_model.wv.index_to_key[:5]

for word in top_5_words:
    print(f"Most similar words to '{word}':")
    print(w2v_model.wv.most_similar(positive=[word]))
    print("-" * 50)
# Out:
# Most similar words to 'I':
# [('look', 0.9998059868812561), (' ', 0.9997839331626892), ('time', 0.9997605681419373), ('plastic', 0.999731719493866), ('little', 0.9997254610061646), ('track', 0.9997186064720154), ('use', 0.9997181296348572), ('also', 0.9997177124023438), ('one', 0.9997150897979736), ('well', 0.9997102618217468)]
# --------------------------------------------------
# Most similar words to ' ':
# [('I', 0.999783992767334), ('like', 0.9997235536575317), ('time', 0.999723494052887), ('end', 0.9997132420539856), ('think', 0.9997113943099976), ('make', 0.9997093677520752), ('one', 0.9997081756591797), ('really', 0.9997033476829529), ('look', 0.9997010231018066), ('also', 0.9996902942657471)]
# --------------------------------------------------
# Most similar words to 'good':
# [('time', 0.9996769428253174), ('one', 0.9996700882911682), ('I', 0.9996670484542847), (' ', 0.9996622204780579), ('would', 0.9996502995491028), ('get', 0.9996485114097595), ('2', 0.9996359944343567), ('look', 0.9996340274810791), ('also', 0.9996328949928284), ('like', 0.9996174573898315)]
# --------------------------------------------------
# Most similar words to 'buy':
# [(' ', 0.9996890425682068), ('I', 0.9996643662452698), ('side', 0.9996549487113953), ('time', 0.9996441006660461), ('really', 0.9996272325515747), ('like', 0.999622642993927), ('would', 0.9996199011802673), ('see', 0.9996191263198853), ('track', 0.9996175169944763), ('get', 0.9996148347854614)]
# --------------------------------------------------
# Most similar words to 'one':
# [('I', 0.999715268611908), (' ', 0.9997080564498901), ('see', 0.9996877908706665), ('time', 0.9996823668479919), ('go', 0.9996764063835144), ('use', 0.9996746182441711), ('good', 0.9996700286865234), ('much', 0.9996654987335205), ('old', 0.9996422529220581), ('like', 0.9996411204338074)]
# --------------------------------------------------

# %%
import matplotlib.pyplot as plt


def drawGraph(bargraph_data, word):
    plt.figure(figsize=(40,10))
    xtick = [item[0] for item in bargraph_data]
    ytick = [item[1] for item in bargraph_data]

    plt.title(f"Top 20 similar words to '{word}'")
    plt.xlabel("Words")
    plt.ylabel("Similarity")
    plt.ylim(0.9995, 1.0)

    mycolors = ['#06c2ac', '#c79fef', '#ff796c', '#aaff32', '#0485d1', '#d648d7', '#a5a502', '#d8dcd6', '#5ca904', '#fffe7a' ]
    plt.bar(xtick, ytick, color=mycolors)
    plt.xticks(rotation=45)  # x축 레이블 회전
    plt.figure()



for word in top_5_words:
    bargraph_data = w2v_model.wv.most_similar(positive=[word], topn=20)
    drawGraph(bargraph_data, word)

# %% [markdown]
# # 8. t-SNE

# %%
from sklearn.manifold import TSNE

word_vectors = w2v_model.wv
vocabs = word_vectors.index_to_key
word_vectors_list = np.array([word_vectors[v] for v in vocabs])

TSNE_model = TSNE(perplexity=5, max_iter=250)
transformed = TSNE_model.fit_transform(word_vectors_list)

xs = transformed[:, 0]
ys = transformed[:, 1]

plt.figure(figsize=(15,15))
plt.scatter(xs, ys)
for i, v in enumerate(vocabs):
    plt.annotate(v, xy=(xs[i], ys[i]))

# %%
# Try modifying the index to display different word vectors from the corresponding vocabulary (word)
print(word_vectors[4])
print(vocabs[4])
# Out:
# [-0.33627766  0.14582115  0.07208815  0.19383468  0.1855686  -0.4108088
#   0.22715372  0.5055393  -0.28346282 -0.04965163 -0.03330348 -0.31586286
#  -0.2292427   0.06276243  0.02317286 -0.33606547  0.05238178 -0.45981857
#  -0.15874116 -0.68653554  0.1487617   0.1640884   0.11820196 -0.13086167
#  -0.00409616 -0.04898566 -0.24489117 -0.3363055  -0.51351017 -0.1875811
#   0.21016853  0.2603872   0.16820978 -0.01129107 -0.16544156  0.71117747
#   0.05141054 -0.32434925 -0.25561208 -0.8413997   0.31559873 -0.5608369
#  -0.35213342  0.03754077  0.37870115  0.02111463 -0.1991365  -0.2035325
#   0.14542161  0.05629566  0.41390976 -0.06944621  0.15368932  0.08892355
#  -0.12700924  0.16686209  0.19138213  0.09247023 -0.6854329   0.16710924
#   0.04625236 -0.08531988  0.22266689 -0.6233047  -0.48192436  0.06228745
#   0.378225    0.42181098 -0.5713148   0.53786856 -0.30657145  0.01028059
#   0.06336499 -0.04962827  0.42099476  0.17808364  0.05878188 -0.06935687
#  -0.53997386  0.32996356 -0.14336947  0.08989552 -0.39045852  0.51829284
#  -0.3659505   0.02522394  0.15666425  0.37647462  0.45627925  0.08253975
#   0.54884374  0.31257868  0.14715405  0.12621412  0.611271    0.5583683
#   0.02661978 -0.2878238   0.20221192  0.03720479]
# one

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import numpy as np

def encode_review_with_dict(review, word_to_rating):
    encoded = [word_to_rating.get(word, word_to_rating['<OOV>']) for word in review]
    return np.bincount(encoded, minlength=6)[1:]  # index 0 is unused

# Build feature matrix
X_train1 = np.array([encode_review_with_dict(r, max_dict) for r in train_df_lemma['review']])
y_train1 = train_df_lemma['rating'].astype(int).values

X_test1 = np.array([encode_review_with_dict(r, max_dict) for r in test_df_lemma['review']])
y_test1 = test_df_lemma['rating'].astype(int).values

# Train and evaluate
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train1, y_train1)
y_pred1 = clf.predict(X_test1)

print("Integer Encoding + Logit:")
print(classification_report(y_test1, y_pred1, zero_division=0))
# Out:
# Integer Encoding + Logit:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         5
#            2       0.00      0.00      0.00         5
#            3       0.25      0.80      0.38         5
#            4       0.67      0.40      0.50         5
#            5       1.00      0.80      0.89         5
#
#     accuracy                           0.40        25
#    macro avg       0.38      0.40      0.35        25
# weighted avg       0.38      0.40      0.35        25

# %%
def average_embedding(review, model):
    vectors = [model.wv[word] for word in review if word in model.wv]
    return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)

# Build feature matrix
X_train2 = np.array([average_embedding(r, w2v_model) for r in train_df_lemma['review']])
y_train2 = train_df_lemma['rating'].astype(int).values

X_test2 = np.array([average_embedding(r, w2v_model) for r in test_df_lemma['review']])
y_test2 = test_df_lemma['rating'].astype(int).values

# Train and evaluate
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train2, y_train2)
y_pred2 = clf.predict(X_test2)

print("Word2Vec + Logit:")
print(classification_report(y_test2, y_pred2, zero_division=0))
# Out:
# Word2Vec + Logit:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         5
#            2       0.00      0.00      0.00         5
#            3       0.25      0.60      0.35         5
#            4       0.00      0.00      0.00         5
#            5       0.17      0.40      0.24         5
#
#     accuracy                           0.20        25
#    macro avg       0.08      0.20      0.12        25
# weighted avg       0.08      0.20      0.12        25

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_model(y_true, y_pred, title):
    print(title)
    print(classification_report(y_true, y_pred, zero_division=0))
    sns.heatmap(confusion_matrix(y_true, y_pred, labels=[1,2,3,4,5]),
                annot=True, fmt='d', cmap='Blues', xticklabels=[1,2,3,4,5], yticklabels=[1,2,3,4,5])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix - {title}")
    plt.yticks(rotation=0)
    plt.show()

evaluate_model(y_test1, y_pred1, "Version 1: Word-to-Index Encoding")
evaluate_model(y_test2, y_pred2, "Version 2: Word2Vec Embedding")
# Out:
# Version 1: Word-to-Index Encoding
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         5
#            2       0.00      0.00      0.00         5
#            3       0.25      0.80      0.38         5
#            4       0.67      0.40      0.50         5
#            5       1.00      0.80      0.89         5
#
#     accuracy                           0.40        25
#    macro avg       0.38      0.40      0.35        25
# weighted avg       0.38      0.40      0.35        25
# Version 2: Word2Vec Embedding
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         5
#            2       0.00      0.00      0.00         5
#            3       0.25      0.60      0.35         5
#            4       0.00      0.00      0.00         5
#            5       0.17      0.40      0.24         5
#
#     accuracy                           0.20        25
#    macro avg       0.08      0.20      0.12        25
# weighted avg       0.08      0.20      0.12        25
